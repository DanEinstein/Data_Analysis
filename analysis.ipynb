# %%
print('Hello World')
print("This is the test of the dataset")
# Out:
# Hello World
# This is the test of the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
print("import successful")
# Out:
# import successful

# %%
# import the dataset using pandas
df = pd.read_csv('healthcare_dataset_messy.csv')
df.head()
#  The head function displays the  first few rows of the dataset. It is useful for quickly testing if your object has the right type of data in it.
# Out:
#   patient_id   first_name  last_name    age  gender  department  \
# 0      P1199  Christopher     Martin   48.0    male   Radiology
# 1      P1175      Anthony      Lopez   74.0     NaN  Psychiatry
# 2      P1140        James     Thomas   76.0       F    Oncology
# 3      P1072        Linda  Rodriguez    6.0     NaN  Psychiatry
# 4      P1187      Michael   Williams  999.0  Female   Neurology
#
#                  diagnosis       admit_date attending_doctor  \
# 0   Chronic Kidney Disease    Jan 07, 2024         Dr. Adams
# 1               Depression       11-11-2025        Dr. Gupta
# 2           Osteoarthritis       17-03-2026        Dr. Gupta
# 3                   Anemia       10/13/2021        Dr. Jones
# 4  Coronary Artery Disease       12/06/2025        Dr. Gupta
#
#   insurance_provider      status billing_amount         phone  \
# 0           Medicare  DISCHARGED         456.75  206-507-4635
# 1              Cigna    admitted       13825.02  772-768-8925
# ...

# %%
# checking the columns of the dataset
print(df.columns)
# Out:
# Index(['patient_id', 'first_name', 'last_name', 'age', 'gender', 'department',
#        'diagnosis', 'admit_date', 'attending_doctor', 'insurance_provider',
#        'status', 'billing_amount', 'phone', 'email'],
#       dtype='str')

# %%
#  checking some basic information about the dataset
print(df.info())
#  good for checking the data types of the columns, the number of non-null values, and the memory usage of the dataset.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          203 non-null    str
#  1   first_name          203 non-null    str
#  2   last_name           203 non-null    str
#  3   age                 199 non-null    float64
#  4   gender              171 non-null    str
#  5   department          183 non-null    str
#  6   diagnosis           180 non-null    str
#  7   admit_date          203 non-null    str
#  8   attending_doctor    158 non-null    str
#  9   insurance_provider  164 non-null    str
#  10  status              171 non-null    str
#  11  billing_amount      198 non-null    str
#  12  phone               203 non-null    str
#  13  email               196 non-null    str
# dtypes: float64(1), str(13)
# memory usage: 22.3 KB
# None

# %%
#  some important values 
print(df.describe())
#  important for the values such as mean, standard deviation, minimum and maximum values, and quartiles of the numerical columns in the dataset.
# Out:
#               age
# count  199.000000
# mean    56.562814
# std     99.217926
# min     -1.000000
# 25%     24.000000
# 50%     47.000000
# 75%     72.000000
# max    999.000000

# %%
#  focus on each column to get more information about the dataset
# focus on patient_id column
df
